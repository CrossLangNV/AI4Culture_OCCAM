# %% [markdown]
# # Evaluation of segmentation algorithms

# %%
# Import modules
from text_parser.sentence_extraction import extract_sentences_from_lines

# %%
# Example of how to use the segmentation module
original_example = [
    "This is a sent-",
    "ence. This is",
    "another sentence.",
    "As you can see, it",
    "is split over multi-",
    "ple lines.",
]
language = "en"

# %%
sentences = extract_sentences_from_lines(original_example, language)

# %%
print(sentences)

# %% [markdown]
# ## Automatic evaluation
#
# - [ ]  TER
# - [ ]  BLEU
# - [ ]  Edit distance

# %%
from sacrebleu import BLEU, TER, CHRF

def TER(reference: list[str], hypotheses: list[str]) -> float:
    """
    Corpus score (single score for all sentences)
    Value between 0 and 1*
        *not necessarily, but usually
    """
    ter = TER()
    corpus_ter = ter.corpus_score(hypotheses, [references])

    # Normalize the score
    score = corpus_ter.score / 100

    return score
    
    return
